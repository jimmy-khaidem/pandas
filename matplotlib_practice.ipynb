# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
speed=[30,20,30,50]
distance=[1,4,6,10]
plt.plot(speed,distance,marker='o')

# %%
x=[1,2,2.2,4]
y=[1,10,7.5,20]
plt.plot(x,y)
plt.show()

# %%
year=[2013,2015,2019,2022]
price=[50,58,69,104]
plt.plot(price,year)
plt.title('petrol price')
plt.xlabel('price')
plt.ylabel('year')
plt.show()

# %%
x=[2018,2019,2020,2021]
y=[50,55,67,150]
z=[60,55,70,120]
plt.plot(x,y)
plt.plot(x,z)
plt.title('goal score')
plt.xlabel('year')
plt.ylabel('goal')
plt.legend(["messi ","neymar"])
plt.show()

# %%
weathertable=pd.read_csv("C:/Users/jimmy/OneDrive/Desktop/Aroha_sql/sql assignment/new1/weather.csv",parse_dates=['day'])
x=weathertable.city.tail(5)
x
# Out:
# 7     mumbai
# 8      paris
# 9      paris
# 10     paris
# 11     paris
# Name: city, dtype: object

# %%
y=weathertable.event.tail(5)
y
# Out:
# 7       Rain
# 8      Sunny
# 9     Cloudy
# 10    Cloudy
# 11    Cloudy
# Name: event, dtype: object

# %%
def graph():
    plt.plot(x,y)
    plt.legend(['city and its weather'])
    plt.show()
graph()

# %%
price=[2013,2015,2019,2022]
year=[50,58,69,104]
plt.bar(price,year)
plt.title('petrol price')
plt.xlabel('price')
plt.ylabel('year')
plt.show()
